# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Insertion des données dans la variable voitures

# %%
voitures = pd.read_csv("datasets_sell_car.csv",sep=",")

# %% [markdown]
# ### Affichage de la variable voitures

# %%
voitures
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura        Integra              16.919               16.360
# 1          Acura             TL              39.384               19.875
# 2          Acura             CL              14.114               18.225
# 3          Acura             RL               8.588               29.725
# 4           Audi             A4              20.397               22.255
# 5           Audi             A6              18.780               23.555
# 6           Audi             A8               1.380               39.000
# 7            BMW           323i              19.747                  NaN
# 8            BMW           328i               9.231               28.675
# 9            BMW           528i              17.527               36.125
# 10         Buick        Century              91.561               12.475
# 11         Buick          Regal              39.350               13.740
# ...

# %% [markdown]
# ### Affichage du nombre total de model Audi vendu en millier

# %%
voitures[voitures.Manufacturer=="Audi"].Sales_in_thousands.sum()
# Out:
# 40.55700000000001

# %% [markdown]
# ### Classement des voitures vendu des plus onéreuse au moins chère

# %%
voitures.sort_values(by="Price_in_thousands", ascending = False)
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 93    Mercedes-B         E-Class              27.602               41.450
# 72         Lexus           GS400               3.334                  NaN
# 18      Cadillac        Escalade              14.785                  NaN
# 24     Chevrolet        Corvette              17.947               36.225
# 155        Volvo             C70               3.493                  NaN
# 15      Cadillac         Seville              15.943               27.100
# 77       Lincoln        Town car              48.911               21.725
# 117     Plymouth         Prowler               1.872                  NaN
# 66        Jaguar          S-Type              15.467                  NaN
# 78       Lincoln       Navigator              22.925                  NaN
# 3          Acura              RL               8.588               29.725
# 98    Mercedes-B       CLK Coupe              11.592                  NaN
# ...

# %% [markdown]
# ### Les modèles de voitures qui consomment le moins

# %%
voitures.sort_values(by="Fuel_efficiency")
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 78       Lincoln       Navigator              22.925                  NaN
# 144       Toyota    Land Cruiser               9.835               34.080
# 74         Lexus           LX470               9.126                  NaN
# 18      Cadillac        Escalade              14.785                  NaN
# 41         Dodge       Ram Wagon              16.767               15.510
# 39         Dodge           Viper               0.916               58.470
# 42         Dodge         Ram Van              31.038               13.425
# 54          Ford      Expedition             125.338               23.575
# 40         Dodge      Ram Pickup             227.061               15.060
# 44         Dodge         Durango             101.323                  NaN
# 67          Jeep        Wrangler              55.557               13.475
# 90       Mercury     Mountaineer              27.609               20.430
# ...

# %% [markdown]
# ### Pour chaque constructeur l'affichage du total des ventes

# %%
voitures.groupby("Manufacturer").Sales_in_thousands.sum()
# Out:
# Manufacturer
# Acura           79.005
# Audi            40.557
# BMW             46.505
# Buick          242.019
# Cadillac       112.178
# Chevrolet      554.365
# Chrysler       201.721
# Dodge          910.149
# Ford          2022.635
# Honda          592.674
# Hyundai        137.326
# Infiniti        23.713
# Jaguar          15.467
# Jeep           293.153
# Lexus          106.843
# Lincoln         85.634
# Mercedes-B     117.125
# Mercury        237.999
# Mitsubishi     180.895
# Nissan         399.635
# Oldsmobile     178.989
# Plymouth        64.001
# Pontiac        370.534
# Porsche         12.128
# Saab            21.306
# Saturn         168.850
# Subaru          80.135
# Toyota         740.205
# Volkswagen     209.212
# Volvo           75.740
# Name: Sales_in_thousands, dtype: float64

# %% [markdown]
# ### Nouveau tableau permettannt de voir pour chaque marque la moyenne du facteur de performance pour les types car et passenger

# %%
average_performance=voitures.pivot_table('Power_perf_factor',index='Manufacturer',columns='Vehicle_type',aggfunc=np.mean)
average_performance
# Out:
# Vehicle_type         Car   Passenger
# Manufacturer
# Acura                NaN   80.346902
# Audi                 NaN   93.999867
# BMW                  NaN   79.022333
# Buick                NaN   84.225272
# Cadillac      109.509117  106.681231
# Chevrolet            NaN   69.041307
# Chrysler             NaN   78.675508
# Dodge          72.525240   90.917462
# Ford           77.309363   62.344052
# Honda          76.302720   48.574323
# Hyundai              NaN   50.006859
# Infiniti             NaN   92.436889
# Jaguar               NaN  102.178985
# Jeep           68.548372         NaN
# Lexus          98.852130  107.904443
# Lincoln       123.972047  103.749062
# Mercedes-B     90.495532  105.058718
# Mercury        77.810603   61.252221
# Mitsubishi     77.290878   63.851170
# Nissan         70.283559   67.661175
# Oldsmobile     78.304122   77.825818
# Plymouth       60.951185   70.827084
# Pontiac        76.208440   74.975571
# Porsche              NaN  121.247672
# ...

# %%
performance=voitures.pivot_table('Power_perf_factor',index ='Horsepower',columns='Manufacturer',aggfunc=np.mean)
performance.plot()

# %% [markdown]
# ## Répartition des prix entre les modèles Audi

# %%
voitures[voitures.Manufacturer=="Audi"].Price_in_thousands.plot()

# %% [markdown]
# ### Evolution de la différence de prix des modèles Audi à la sortie et après un an

# %%
voitures[voitures.Manufacturer=="Audi"].Price_in_thousands.plot()
voitures[voitures.Manufacturer=="Audi"].__year_resale_value.plot()
